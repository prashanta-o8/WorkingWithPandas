# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Prashanta Saha\Downloads\data\survey_results_public.csv')
schema_df = pd.read_csv(r'C:\Users\Prashanta Saha\Downloads\data\survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# 0          NaN
# 1          NaN
# 2       8820.0
# 3      61000.0
# 4          NaN
# 5     366420.0
# 6          NaN
# 7          NaN
# 8      95179.0
# 9      13293.0
# 10         NaN
# 11         NaN
# 12     90000.0
# 13     57060.0
# 14         NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.median()
# Out:
# C:\Users\Prashanta Saha\AppData\Local\Temp\ipykernel_3620\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df['Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %%
filt = df['Country'] == 'Bangladesh'
df.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 41             42                     I am a developer by profession      Yes
# 169           171             I am a student who is learning to code      Yes
# 298           300             I am a student who is learning to code       No
# 322           324                     I am a developer by profession      Yes
# 687           690  I used to be a developer by profession, but no...       No
# ...           ...                                                ...      ...
# 88576       40072                                                NaN      Yes
# 88731       62740                                                NaN       No
# 88743       64910                                                NaN       No
# 88815       78004                                                NaN      Yes
# 88834       81624                                                NaN      Yes
#
# ...

# %%
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Facebook                    313
# YouTube                     137
# LinkedIn                     62
# Twitter                      19
# I don't use social media     17
# WhatsApp                     14
# Reddit                        9
# Instagram                     8
# Snapchat                      2
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
df.loc[filt]['ConvertedComp'].value_counts()
# Out:
# 3588.0     18
# 7164.0     16
# 5736.0     15
# 14340.0    12
# 4296.0      9
#            ..
# 20184.0     1
# 119.0       1
# 6000.0      1
# 5100.0      1
# 40000.0     1
# Name: ConvertedComp, Length: 118, dtype: int64

# %%
df.loc[filt]['ConvertedComp'].describe()
# Out:
# count    2.500000e+02
# mean     2.124965e+04
# std      8.426553e+04
# min      0.000000e+00
# 25%      5.016000e+03
# 50%      8.764000e+03
# 75%      1.708725e+04
# max      1.200000e+06
# Name: ConvertedComp, dtype: float64

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['Belgium']
# Out:
# SocialMedia
# Reddit                      150
# WhatsApp                    121
# Facebook                    118
# YouTube                     110
# Twitter                      85
# I don't use social media     46
# LinkedIn                     41
# Instagram                    29
# Snapchat                      2
# Hello                         1
# WeChat 微信                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['ConvertedComp'].median().nlargest(10)
# Out:
# Country
# Liechtenstein                       811188.0
# San Marino                          301788.0
# Timor-Leste                         229500.0
# Andorra                             160931.0
# Democratic Republic of the Congo    110484.0
# United States                       110000.0
# Switzerland                          95440.0
# Israel                               90720.0
# Ireland                              83640.0
# Denmark                              82860.0
# Name: ConvertedComp, dtype: float64

# %%
country_grp['ConvertedComp'].median().nsmallest(10)
# Out:
# Country
# Gabon                      0.0
# Guinea                  1956.0
# Sudan                   2016.0
# Syrian Arab Republic    2742.0
# Burundi                 3606.0
# Cuba                    3666.0
# Madagascar              4074.0
# Togo                    4188.0
# Nepal                   4224.0
# Myanmar                 4806.0
# Name: ConvertedComp, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    5739
# True     3105
# Name: LanguageWorkedWith, dtype: int64

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns')
python_df.head()
# Out:
#                 Country  LanguageWorkedWith
# United States     20949               10083
# India              9061                3105
# Germany            5866                2451
# United Kingdom     5737                2384
# Canada             3395                1558

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                    NumRespondents  NumKnowsPython
# United States               20949           10083
# India                        9061            3105
# Germany                      5866            2451
# United Kingdom               5737            2384
# Canada                       3395            1558
# ...                           ...             ...
# Tonga                           1               0
# Timor-Leste                     1               1
# North Korea                     1               0
# Brunei Darussalam               1               0
# Chad                            1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                    NumRespondents  NumKnowsPython  PctKnowsPython
# United States               20949           10083       48.131176
# India                        9061            3105       34.267741
# Germany                      5866            2451       41.783157
# United Kingdom               5737            2384       41.554820
# Canada                       3395            1558       45.891016
# ...                           ...             ...             ...
# Tonga                           1               0        0.000000
# Timor-Leste                     1               1      100.000000
# North Korea                     1               0        0.000000
# Brunei Darussalam               1               0        0.000000
# Chad                            1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.loc['Bangladesh']
# Out:
# NumRespondents    605.000000
# NumKnowsPython    204.000000
# PctKnowsPython     33.719008
# Name: Bangladesh, dtype: float64

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Dominica                                       1               1
# Niger                                          1               1
# Turkmenistan                                   7               6
# ...                                          ...             ...
# Cape Verde                                     3               0
# Lao People's Democratic Republic               3               0
# Malawi                                         2               0
# Liberia                                        2               0
# Chad                                           1               0
#
#                                   PctKnowsPython
# Sao Tome and Principe                 100.000000
# Timor-Leste                           100.000000
# ...
